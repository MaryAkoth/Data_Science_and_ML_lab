# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
#importing my dataset
df = pd.read_csv("/content/cliff.csv")

#loading the fist 4 rows of the dataset
df.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#loading the last 5 rows of the dataset
df.tail(5)
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ### Distribution of Data

# %%
#histogram distribution of age
plt.hist(df['Age'], bins=10, color= "purple", edgecolor = "black")
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#histogram distribution of Height
plt.hist(df['Height'], bins=10, color= "orange", edgecolor = "black")
plt.title("Distribution of Height")
plt.xlabel("Height")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#histogram distribution of Season
plt.hist(df['Season'], bins=10, color= "orange", edgecolor = "black")
plt.title("Distribution of Season")
plt.xlabel("Season")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Descriptive statistics

# %%
# Create histograms
plt.figure(figsize=(18, 6))

# Symmetrical distribution
plt.subplot(1, 3, 1)
plt.hist(df['Age'], bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Negative skew distribution
plt.subplot(1, 3, 3)
plt.hist(df['Height'], bins=30, color='lightgreen', edgecolor='black')
plt.title('Height Distribution')
plt.xlabel('Height')



# Positive skew distribution
plt.subplot(1, 3, 2)
plt.hist(df['Weight'], bins=30, color='red', edgecolor='black')
plt.title("Weight Distribution")
plt.xlabel('Weight')



plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Cleaning

# %%
#checking duplicates
df[df.duplicated]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1252       704                   Dsir Antoine Acket   M  27.0     NaN     NaN
# 4282      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4283      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4862      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# 4864      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0     NaN     NaN
# 270200  135173                     Henri Achille Zo   M  58.0     NaN     NaN
#
# ...

# %%
#For the confirmation of duplicates

df[df["ID"]==2449]
# Out:
#         ID                    Name Sex   Age  Height  Weight           Team  \
# 4281  2449  William Truman Aldrich   M  48.0     NaN     NaN  United States
# 4282  2449  William Truman Aldrich   M  48.0     NaN     NaN  United States
# 4283  2449  William Truman Aldrich   M  48.0     NaN     NaN  United States
#
#       NOC        Games  Year  Season       City             Sport  \
# 4281  USA  1928 Summer  1928  Summer  Amsterdam  Art Competitions
# 4282  USA  1928 Summer  1928  Summer  Amsterdam  Art Competitions
# 4283  USA  1928 Summer  1928  Summer  Amsterdam  Art Competitions
#
#                                                   Event Medal
# 4281  Art Competitions Mixed Painting, Drawings And ...   NaN
# 4282  Art Competitions Mixed Painting, Drawings And ...   NaN
# 4283  Art Competitions Mixed Painting, Drawings And ...   NaN

# %%
#dropping all duplicates
df_new = df.drop_duplicates()

df_new.shape
# Out:
# (269731, 15)

# %%
df_new[df_new.duplicated]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
#confirming absence of  null values
df_new.isnull()
# Out:
#            ID   Name    Sex    Age  Height  Weight   Team    NOC  Games  \
# 0       False  False  False  False   False   False  False  False  False
# 1       False  False  False  False   False   False  False  False  False
# 2       False  False  False  False    True    True  False  False  False
# 3       False  False  False  False    True    True  False  False  False
# 4       False  False  False  False   False   False  False  False  False
# ...       ...    ...    ...    ...     ...     ...    ...    ...    ...
# 271111  False  False  False  False   False   False  False  False  False
# 271112  False  False  False  False   False   False  False  False  False
# 271113  False  False  False  False   False   False  False  False  False
# 271114  False  False  False  False   False   False  False  False  False
# 271115  False  False  False  False   False   False  False  False  False
#
#          Year  Season   City  Sport  Event  Medal
# 0       False   False  False  False  False   True
# ...

# %%
df_new["Medal"].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df_new["Medal"] = df_new["Medal"].fillna("no_medal")

# %% [markdown]
# ### Handling null of age

# %%
df_new['Age'] = df_new['Age'].astype('float64')

# %%
#calculate the median age
median_age = df_new['Age'].median()

# Fill NaN values with median age
df_new['Age'] = df_new['Age'].fillna(median_age)

# %%
#calculate the median age
mean_height = df_new['Height'].mean()

# Fill NaN values with median age
df_new['Height'] = df_new['Height'].fillna(mean_height)

# %%
#calculate the median age
mean_weight = df_new['Weight'].mean()

# Fill NaN values with median age
df_new['Weight'] = df_new['Weight'].fillna(median_age)

# %%
df['Team'].unique()
# Out:
# array(['China', 'Denmark', 'Denmark/Sweden', ..., 'Solos Carex',
#        'Dow Jones', 'Digby'], dtype=object)

# %%
df['Team'].nunique()
# Out:
# 1184

# %%
df_new['Sex'] = df_new['Sex'].astype('category')
df_new['Age'] = df_new['Age'].astype('int')
df_new['Team'] = df_new['Team'].astype('category')
df_new['Medal'] = df_new['Medal'].astype('category')
df_new['NOC'] = df_new['NOC'].astype('category')

# %%
df_new.dtypes
# Out:
# ID           int64
# Name        object
# Sex       category
# Age          int64
# Height     float64
# Weight     float64
# Team      category
# NOC       category
# Games       object
# Year         int64
# Season      object
# City        object
# Sport       object
# Event       object
# Medal     category
# dtype: object

# %%
df_new.head()
# Out:
#    ID                      Name Sex  Age      Height  Weight            Team  \
# 0   1                 A Dijiang   M   24  180.000000    80.0           China
# 1   2                  A Lamusi   M   23  170.000000    60.0           China
# 2   3       Gunnar Nielsen Aaby   M   24  175.338953    24.0         Denmark
# 3   4      Edgar Lindenau Aabye   M   34  175.338953    24.0  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F   21  185.000000    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event     Medal
# 0       Basketball Men's Basketball  no_medal
# 1      Judo Men's Extra-Lightweight  no_medal
# ...

# %% [markdown]
# ### EDA

# %%
#Feature engineering
df_new["Height"] = df_new["Height"] / 100

df_new["BMI"] = df_new["Weight"]/ df_new["Height"] ** 2

# %%
df_new["BMI"]
# Out:
# 0         24.691358
# 1         20.761246
# 2          7.806465
# 3          7.806465
# 4         23.959094
#             ...
# 271111    27.776911
# 271112    19.047004
# 271113    19.047004
# 271114    28.049671
# 271115    28.049671
# Name: BMI, Length: 269731, dtype: float64

# %%
df_new.head(10)
# Out:
#    ID                      Name Sex  Age   Height  Weight            Team  \
# 0   1                 A Dijiang   M   24  1.80000    80.0           China
# 1   2                  A Lamusi   M   23  1.70000    60.0           China
# 2   3       Gunnar Nielsen Aaby   M   24  1.75339    24.0         Denmark
# 3   4      Edgar Lindenau Aabye   M   34  1.75339    24.0  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F   21  1.85000    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F   21  1.85000    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F   25  1.85000    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F   25  1.85000    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F   27  1.85000    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F   27  1.85000    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
#sex  vrs Medal

df_new.groupby(df_new["Sex"]) ["Medal"].value_counts().to_frame()
# Out:
#                Medal
# Sex Medal
# F   no_medal   63125
#     Bronze      3771
#     Gold        3747
#     Silver      3735
# M   no_medal  166834
#     Gold        9622
#     Bronze      9524
#     Silver      9373
