# %% [markdown]
# # PYTHON PROGRAMMING LANGUAGE

# %%
firstname = 'Mary'
print(firstname)
# Out:
# Mary

# %%
x = 2
y = 3.14
z = 2 + 3j

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(type(z))
# Out:
# <class 'complex'>

# %% [markdown]
# ## Sequence

# %%
list_ = [1,2,3,4,5]
tuple_ = (1,2,3,4,5)
range_ = range(1,5)

# %%
print(type(list_))
# Out:
# <class 'list'>

# %%
print(type(tuple_))
# Out:
# <class 'tuple'>

# %%
print(type(range_))
# Out:
# <class 'range'>

# %%
list_ = [1,2,3,4,5]
print(type(list_))
# Out:
# <class 'list'>

# %% [markdown]
# ## Mapping

# %%
parocyber = {'name': 'Mary',"age": 20,'sport':'rollball','food':'ugali'}

# %%
parocyber['name']
# Out:
# 'Mary'

# %%
Kenya  = {'Central':'Kiambu','Western':'Kakamega','Eastern':'nyeri', 'Northern':'Turkana'}
print(Kenya)
# Out:
# {'Central': 'Kiambu', 'Western': 'Kakamega', 'Eastern': 'nyeri', 'Northern': 'Turkana'}

# %%
Kenya['Central']
# Out:
# 'Kiambu'

# %%
Kenya = {'Nairobi':'Utawala','Kisumu':'Kondele','Migori':'Uwasi border'}
print(Kenya)
# Out:
# {'Nairobi': 'Utawala', 'Kisumu': 'Kondele', 'Migori': 'Uwasi border'}

# %%
Kenya['Nairobi']
# Out:
# 'Utawala'
